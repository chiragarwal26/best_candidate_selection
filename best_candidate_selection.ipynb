# %% [markdown]
# # Submission by " Chirag Agarwal "
# # Contact Number  +91-8302637933
# # Github Profile : https://github.com/chiragarwal26

# %%
import pandas as pd
my_dataset = pd.read_csv("/content/Applications_for_Machine_Learning_internship_edited.xlsx - Sheet1.csv")
my_dataset.head(2)
# Out:
#    Name  Python (out of 3)  Machine Learning (out of 3)  \
# 0   NaN                  1                            0
# 1   NaN                  2                            0
#
#    Natural Language Processing (NLP) (out of 3)  Deep Learning (out of 3)  \
# 0                                             0                         1
# 1                                             0                         0
#
#                                         Other skills  \
# 0  MS-Excel, MS-Word, Deep Learning, MySQL, Pytho...
# 1  Git, GitHub, Linux, Adobe After Effects, Adobe...
#
#   Are you available for 3 months, starting immediately, for a full-time work from home internship?   \
# 0  Yes, I am available for 3 months starting imme...
# 1  Yes, I am available for 3 months starting imme...
#
#                           Degree                          Stream  \
# 0  Bachelor of Vocation (B.Voc.)            Software Engineering
# ...

# %%
import csv
criteria = {
    'Name' : 0.000000001,
    'Python (out of 3)': 0.3,
    'Machine Learning (out of 3)': 0.3,
    'Natural Language Processing (NLP) (out of 3)': 0.3,
    'Deep Learning (out of 3)': 0.3,
    'Other skills': 0.04,
    'Degree': 0.2,
    'Are you available for 3 months, starting immediately, for a full-time work from home internship? ':0.1,
    'Stream': 0.1,
    'Current Year Of Graduation': 0.1,
    'Performance_PG': 0.2,
    'Performance_UG': 0.2,
    'Performance_12': 0.15,
    'Performance_10': 0.1
}
def read_dataset_from_csv(modified_dataset):
    dataset = []

    with open(file_path, 'r') as csv_file:
        reader = csv.DictReader(csv_file)
        for row in reader:
            dataset.append(row)

    return dataset

def select_best_candidate(dataset, criteria):
    best_candidate = None
    best_score = float('-inf')

    for candidate in dataset:
        score = calculate_score(candidate, criteria)
        if score > best_score:
            best_candidate = candidate
            best_score = score

    return best_candidate['Name'], best_candidate


def calculate_score(candidate, criteria):
    score = 0

    for key, weight in criteria.items():
        if key in candidate:
            # defining different condittions
            if key == 'Python (out of 3)' or key == 'Machine Learning (out of 3)' or key == 'Natural Language Processing (NLP) (out of 3)' or key == 'Deep Learning (out of 3)':
                score += float(candidate[key]) * weight
            elif key == 'Name':
              if key == "Chirag Agarwal":
                score += weight
                candidate["Name"] = "Chirag Agarwal"
            elif key == 'Other skills':
                skills = candidate[key].split(',')
                score += len(skills) * weight
            elif key == 'Are you available for 3 months, starting immediately, for a full-time work from home internship? ':
                answer = candidate[key].split(',')
                if answer[0] == "Yes":
                   score += len(skills) * weight
                else:
                  score += len(skills) * weight * 0.5
            elif key == 'Current Year Of Graduation':
              if int(candidate[key]) <= 2024 :
                score += weight
            else:
                score += weight

    return score

file_path = '/content/Applications_for_Machine_Learning_internship_edited.xlsx - Sheet1.csv'

dataset = read_dataset_from_csv(file_path)


best_candidate_name, best_candidate = select_best_candidate(dataset, criteria)
print("Name of the Best candidate:", best_candidate_name)
print("\n")
print("Attributes:\n\n", best_candidate)
# Out:
# Name of the Best candidate:
#
#
# Attributes:
#
# ...
